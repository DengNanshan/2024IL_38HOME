# %% [markdown]
# 1. 地图的地理特异性只能是环境模型 world model 。因为world model可以和决策解耦
#
# 2. 第五章的融合其实是如何把位置相关的world model 和原始决策无缝衔接。简单的方法是获取各种worldmodel 的预存结果。以一种组合的方式。 最大互信息编码，编码空间融合了不同world model的影响，降低了模型大小和处理。

# %% [markdown]
# 1. 提取不应该只是做一个VAE，内在是什么？
#
# 回答： VAE是技术而不是问题。内在是要解决，什么样的地域信息是好用的，能用的。
# 什么信息好用呢？是能区分决策表现的信息。
# 什么样的信息能区分决策表现，就是环境的行为模型。
# 我们通过环境的行为参数统计来描述行为模型
# 使用VAE来压缩原始行为。@a
#
# 其中环境表现和决策算法相关。因此原始存储中不应该与算法关联太强。
# 因此应该包含两部。一是提取压缩所有与决策相关的(地理位置)信息。二将与实际决策相关的信息收集。 @ b
#
#
# 实际上就应该与算法强相关。
#
# 但实际上环境模型可以解耦

# %% [markdown]
# a.
# 这里的原始行为需要能够区分环境表现

# %% [markdown]
# b.
# 矛盾点在于，说是和决策相关的信息，还不能是决策的函数。这点是矛盾的。因此需要紧密和决策结合？但是这样就不专用了。
# 到底是专用还是通用。专用的化只能服务于一种决策，公用的化和决策没有意义，之变成了一个信息提供者。
#
# 但是实际上，“环境模型”和"决策"是能够解耦的
#
# 本质上是制作环境模型。融合的过程实际上是如何根据环境模型来生成策略。多个环境模型共同生成策略，
